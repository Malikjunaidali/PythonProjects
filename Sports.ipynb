# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel(r"F:\python\Data Analysis Projects\Sports Dataset\1 - 2019 ODI Cricket Matches.xlsx")
df
# Out:
#           Team 1        Team 2        Winner     Margin       Ground  \
# 0    New Zealand      Pakistan   New Zealand    61 runs   Wellington
# 1    New Zealand      Pakistan   New Zealand  8 wickets       Nelson
# 2         U.A.E.       Ireland       Ireland  4 wickets   ICCA Dubai
# 3    New Zealand      Pakistan   New Zealand   183 runs      Dunedin
# 4         U.A.E.       Ireland       Ireland    67 runs   ICCA Dubai
# ..           ...           ...           ...        ...          ...
# 123    Australia  South Africa  South Africa    40 runs       Hobart
# 124  New Zealand      Pakistan     no result        NaN  Dubai (DSC)
# 125   Bangladesh   West Indies    Bangladesh  5 wickets        Dhaka
# 126   Bangladesh   West Indies   West Indies  4 wickets        Dhaka
# 127   Bangladesh   West Indies    Bangladesh  8 wickets       Sylhet
#
#     Match Date   Scorecard
# 0   2018-01-06  ODI # 3946
# 1   2018-01-09  ODI # 3947
# 2   2018-01-11  ODI # 3948
# ...

# %% [markdown]
# Task 1: Transform the 'margin' column into two, one for wickets and other for runs!

# %%
import re
file = df['Margin']
resultt =re.match("(r\w+)",file)
df.insert(5,"Win by Runs", resultt  )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-06a6c0f8e9a0> in <module>
#       1 import re
#       2 file = df['Margin']
# ----> 3 resultt =re.match("(r\w+)",file)
#       4 df.insert(5,"Win by Runs", resultt  )
#
# ~\miniconda3\envs\data_analysis\lib\re.py in match(pattern, string, flags)
#     189     """Try to apply the pattern at the start of the string, returning
#     190     a Match object, or None if no match was found."""
# --> 191     return _compile(pattern, flags).match(string)
#     192
#     193 def fullmatch(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object
